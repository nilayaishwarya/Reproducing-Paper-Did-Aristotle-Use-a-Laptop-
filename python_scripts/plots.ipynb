# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
paths = [('/home/jupyter/src/strategyqa/output_ir-ora-d/', "original"), 
         #('/home/jupyter/src/strategyqa/output_newboolq_ir-ora-d/', "new BoolQ"), 
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper0/', "Attempt 0"),
         #'/home/jupyter/src/strategyqa/output_ir-ora-d_hyper0_10epochs/', 

         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper1/',"Attempt 1"),
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper2/', "Attempt 2"),
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper3/',"Attempt 3"),
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper4/',"Attempt 4"),
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper5/',"Attempt 5"),
         ('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper6/', "Attempt 6"),
         ('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper7/', "Attempt 7"),
         #('/home/jupyter/src/strategyqa/output_ir-ora-d_hyper8/', "Attempt 8")

        ]#,'/home/jupyter/src/strategyqa/output_ir-ora-d_hyper2/','/home/jupyter/src/strategyqa/output_ir-ora-d_hyper3/']

# %%
from plot_metrics import plot_metrics

# %%
plot_metrics(paths)
